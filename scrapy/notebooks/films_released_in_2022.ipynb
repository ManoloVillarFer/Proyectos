# %% [markdown]
# # Instalación de líbrerias

# %%
# !pip3 install pandas ipykernel scrapy

# %% [markdown]
# # Inicialización del proyecto

# %%
# !scrapy startproject imdb films_released_in_2022/
# Out:
# Error: scrapy.cfg already exists in /home/manolo/Escritorio/Estudios/Estudios/IA Big Data/Programación de Inteligencia Artificial/films_released_in_2022/notebooks/films_released_in_2022

# %%
# !cd films_released_in_2022 && scrapy genspider "movies-released-in-2022" "https://www.imdb.com/search/title/?release_date=2022-01-01,2022-12-31&runtime=1,&count=250"
# Out:
# Spider 'movies-released-in-2022' already exists in module:
#   imdb.spiders.movies_released_in_2022

# %% [markdown]
# # Lanzamos la araña

# %%
# !cd films_released_in_2022 && scrapy crawl "movies-released-in-2022"
# Out:
# 2023-02-13 14:09:28 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: imdb)
# 2023-02-13 14:09:28 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.10.6 (main, Nov 14 2022, 16:10:14) [GCC 11.3.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.1, Platform Linux-5.15.0-58-generic-x86_64-with-glibc2.35
# 2023-02-13 14:09:28 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'imdb',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'imdb.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['imdb.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-02-13 14:09:28 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-02-13 14:09:28 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# ...

# %% [markdown]
# # Conversión de los datos

# %%
# !mkdir -p datasets
# !cd films_released_in_2022 && scrapy crawl "movies-released-in-2022" -O ../datasets/films_released_in_2022.csv
# Out:
# 2023-02-13 14:09:44 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: imdb)
# 2023-02-13 14:09:44 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.14, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.10.6 (main, Nov 14 2022, 16:10:14) [GCC 11.3.0], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.1, Platform Linux-5.15.0-58-generic-x86_64-with-glibc2.35
# 2023-02-13 14:09:44 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'imdb',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'imdb.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['imdb.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-02-13 14:09:44 [asyncio] DEBUG: Using selector: EpollSelector
# 2023-02-13 14:09:44 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# ...

# %% [markdown]
# # Visualización de los datos

# %%
import pandas as pd
df = pd.read_csv("datasets/films_released_in_2022.csv")
print(len(df))
pd.set_option("display.max_rows", 500)
print(df)
# Out:
# 500
#                                                  title  year  duration  \
# 0                       Black Panther: Wakanda Forever  2022       161
# 1                                              Babylon  2022       189
# 2                                                 1923  2022        60
# 3                             Avatar: The Way of Water  2022       192
# 4                                             The Menu  2022       107
# 5                            The Banshees of Inisherin  2022       114
# 6                    Everything Everywhere All at Once  2022       139
# 7                                            Wednesday  2022        45
# 8                         Puss in Boots: The Last Wish  2022       102
# 9                                                M3GAN  2022       102
# 10                                           The Whale  2022       117
# 11                                     Shotgun Wedding  2022       100
# ...

# %%
# !pip3 install pandas-profiling[notebook]

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df, explorative = True)
profile
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.56it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-02-13 13:10:03.137604&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# !mkdir -p reports
profile.to_file("reports/films_released_in_2022.html")
# Out:
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 257.29it/s]
